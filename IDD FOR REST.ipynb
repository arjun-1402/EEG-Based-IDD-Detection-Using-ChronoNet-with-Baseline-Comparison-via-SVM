# %% [markdown]
# <div style="border: 5px solid #000000;background-color: beige;padding: 10px;">
#
# <h1 style="color:blue; text-align:center;">IDD IDENTIFICATION FOR REST-EEG</h1>
#
# </div>

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
import numpy as np
import pandas as pd
from glob import glob
import scipy.io
import mne
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense, concatenate, GRU, Conv1D, Dropout
from tensorflow.keras.models import Model
import contextlib
import io
from sklearn.metrics import accuracy_score, precision_score

IDD_data_path = './DATASET/Data/CleanData/CleanData_IDD/Rest'
TDC_data_path = './DATASET/Data/CleanData/CleanData_TDC/Rest'
channel_names = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']

def convertmat2mne(data):
    ch_types = ['eeg'] * 14
    info = mne.create_info(channel_names, ch_types=ch_types, sfreq=128)
    info.set_montage('standard_1020')
    data = mne.io.RawArray(data, info)
    data.set_eeg_reference()
    data.notch_filter(freqs=50)
    data.filter(l_freq=1, h_freq=30)
    return mne.make_fixed_length_epochs(data, duration=4).get_data()

@contextlib.contextmanager
def suppress_stdout():
    stdout = io.StringIO()
    with contextlib.redirect_stdout(stdout):
        yield

idd_subject, tdc_subject = [], []
for idd in glob(IDD_data_path + '/*.mat'):
    with suppress_stdout():
        idd_subject.append(convertmat2mne(scipy.io.loadmat(idd)['clean_data']))
for tdc in glob(TDC_data_path + '/*.mat'):
    with suppress_stdout():
        tdc_subject.append(convertmat2mne(scipy.io.loadmat(tdc)['clean_data']))

control_labels = [len(i) * [0] for i in tdc_subject]
patient_labels = [len(i) * [1] for i in idd_subject]
data_list = tdc_subject + idd_subject
label_list = control_labels + patient_labels
groups_list = [[i] * len(j) for i, j in enumerate(data_list)]
data_array = np.moveaxis(np.concatenate(data_list), 1, 2)
label_array, group_array = np.concatenate(label_list), np.concatenate(groups_list)

# %% [markdown]
# ## Feature Extraction and Channel Selection

# %%
feature_list, feature_names = [], []

for i in range(14):
    channel_mean = np.mean(data_array[:, :, i], axis=1)
    channel_var = np.var(data_array[:, :, i], axis=1)
    feature_list.extend([channel_mean, channel_var])
    feature_names.extend([f'{channel_names[i]}_mean', f'{channel_names[i]}_var'])

features_df = pd.DataFrame(np.array(feature_list).T, columns=feature_names)
correlation_values = [abs(np.corrcoef(features_df[f], label_array)[0, 1]) for f in feature_names]

correlation_df = pd.DataFrame({'Feature': feature_names, 'Correlation': correlation_values})
correlation_df['Channel'] = correlation_df['Feature'].str.extract(r'(AF3|F7|F3|FC5|T7|P7|O1|O2|P8|T8|FC6|F4|F8|AF4)')
channel_correlation = correlation_df.groupby('Channel')['Correlation'].max().reset_index()
top_channels = channel_correlation.sort_values(by='Correlation', ascending=False).head(8)['Channel'].tolist()
selected_indices = [channel_names.index(ch) for ch in top_channels]
data_array_selected = data_array[:, :, selected_indices]

class StandardScaler3D(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.scaler = StandardScaler()

    def fit(self, X, y=None):
        self.scaler.fit(X.reshape(-1, X.shape[2]))
        return self

    def transform(self, X):
        return self.scaler.transform(X.reshape(-1, X.shape[2])).reshape(X.shape)

gkf = GroupKFold()
accuracy, precision_scores = [], []

# %%
print(top_channels)
# Out:
# ['T8', 'FC6', 'F4', 'AF4', 'P8', 'AF3', 'FC5', 'F3']

# %% [markdown]
# ## Model Training, Evaluation, and Plotting

# %%
for train_index, val_index in gkf.split(data_array_selected, label_array, groups=group_array):
    train_features, train_labels = data_array_selected[train_index], label_array[train_index]
    val_features, val_labels = data_array_selected[val_index], label_array[val_index]

    scaler = StandardScaler3D()
    train_features = scaler.fit_transform(train_features)
    val_features = scaler.transform(val_features)

    def block(input):
        conv1 = Conv1D(32, 2, strides=2, activation='relu', padding="same")(input)
        conv2 = Conv1D(32, 4, strides=2, activation='relu', padding="causal")(input)
        conv3 = Conv1D(32, 8, strides=2, activation='relu', padding="causal")(input)
        return concatenate([conv1, conv2, conv3], axis=2)

    input = Input(shape=(512, 8))
    block1 = block(input)
    block2 = block(block1)
    block3 = block(block2)

    gru_out1 = GRU(32, activation='tanh', return_sequences=True)(block3)
    gru_out2 = GRU(32, activation='tanh', return_sequences=True)(gru_out1)
    gru_out = concatenate([gru_out1, gru_out2], axis=2)
    gru_out3 = GRU(32, activation='tanh', return_sequences=True)(gru_out)
    gru_out = concatenate([gru_out1, gru_out2, gru_out3])
    gru_out4 = GRU(32, activation='tanh')(gru_out)

    dropout = Dropout(0.5)(gru_out4)
    predictions = Dense(1, activation='sigmoid')(dropout)
    model = Model(inputs=input, outputs=predictions)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    history = model.fit(train_features, train_labels, epochs=30, batch_size=128, validation_data=(val_features, val_labels))

    val_predictions = (model.predict(val_features) > 0.5).astype(int)
    accuracy.append(accuracy_score(val_labels, val_predictions))
    precision_scores.append(precision_score(val_labels, val_predictions))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy with Dropout Regularization')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss with Dropout Regularization')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

print("Average Accuracy: ", np.mean(accuracy))
print("Average Precision: ", np.mean(precision_scores))
# Out:
# Epoch 1/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 486ms/step - accuracy: 0.5174 - loss: 0.6737 - val_accuracy: 0.6000 - val_loss: 0.6790
# Epoch 2/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7710 - loss: 0.6130 - val_accuracy: 0.7222 - val_loss: 0.6354
# Epoch 3/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9340 - loss: 0.4827 - val_accuracy: 0.7556 - val_loss: 0.5456
# Epoch 4/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9521 - loss: 0.3096 - val_accuracy: 0.7667 - val_loss: 0.4850
# Epoch 5/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9776 - loss: 0.1621 - val_accuracy: 0.8111 - val_loss: 0.3998
# Epoch 6/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9858 - loss: 0.0842 - val_accuracy: 0.6889 - val_loss: 0.9710
# Epoch 7/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9900 - loss: 0.0409 - val_accuracy: 0.8556 - val_loss: 0.4175
# Epoch 8/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9882 - loss: 0.0391 - val_accuracy: 0.6889 - val_loss: 1.1920
# Epoch 9/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9929 - loss: 0.0348 - val_accuracy: 0.7889 - val_loss: 0.7486
# Epoch 10/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9972 - loss: 0.0099 - val_accuracy: 0.8444 - val_loss: 0.5160
# Epoch 11/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.6778 - val_loss: 1.4894
# Epoch 12/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9976 - loss: 0.0091 - val_accuracy: 0.6778 - val_loss: 1.4122
# Epoch 13/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8000 - val_loss: 0.8204
# Epoch 14/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8667 - val_loss: 0.5131
# Epoch 15/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8333 - val_loss: 0.4547
# Epoch 16/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8667 - val_loss: 0.4708
# Epoch 17/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8444 - val_loss: 0.4873
# Epoch 18/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8778 - val_loss: 0.4482
# Epoch 19/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8444 - val_loss: 0.4471
# Epoch 20/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8556 - val_loss: 0.4709
# Epoch 21/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8778 - val_loss: 0.4991
# Epoch 22/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8889 - val_loss: 0.5311
# Epoch 23/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8889 - val_loss: 0.5670
# Epoch 24/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8667 - val_loss: 0.6036
# Epoch 25/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8556 - val_loss: 0.6380
# Epoch 26/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8333 - val_loss: 0.6648
# Epoch 27/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8222 - val_loss: 0.6827
# Epoch 28/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8111 - val_loss: 0.6964
# Epoch 29/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8111 - val_loss: 0.7064
# Epoch 30/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8111 - val_loss: 0.7119
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 336ms/step
# Epoch 1/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 8s 471ms/step - accuracy: 0.4994 - loss: 0.6915 - val_accuracy: 0.3778 - val_loss: 0.6915
# Epoch 2/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.6376 - loss: 0.6446 - val_accuracy: 0.8444 - val_loss: 0.6110
# Epoch 3/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8497 - loss: 0.5529 - val_accuracy: 0.9556 - val_loss: 0.4483
# Epoch 4/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9385 - loss: 0.3795 - val_accuracy: 0.9889 - val_loss: 0.2153
# Epoch 5/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9567 - loss: 0.1999 - val_accuracy: 0.9889 - val_loss: 0.0856
# Epoch 6/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9648 - loss: 0.1142 - val_accuracy: 0.9778 - val_loss: 0.0550
# Epoch 7/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9868 - loss: 0.0489 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 8/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9939 - loss: 0.0267 - val_accuracy: 0.9556 - val_loss: 0.1501
# Epoch 9/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9827 - loss: 0.0480 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 10/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9784 - loss: 0.0540 - val_accuracy: 0.9889 - val_loss: 0.0281
# Epoch 11/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9866 - loss: 0.0194 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 12/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 13/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9972 - loss: 0.0132 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 14/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 15/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9976 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 16/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 17/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 9.7194e-04
# Epoch 18/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 8.8843e-04
# Epoch 19/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 8.3762e-04
# Epoch 20/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 8.0107e-04
# Epoch 21/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 7.7171e-04
# Epoch 22/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 7.4495e-04
# Epoch 23/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 7.1979e-04
# Epoch 24/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 6.9696e-04
# Epoch 25/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 6.7564e-04
# Epoch 26/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 6.5628e-04
# Epoch 27/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 6.3898e-04
# Epoch 28/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 6.2274e-04
# Epoch 29/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 6.0709e-04
# Epoch 30/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 5.9212e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step
# Epoch 1/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 535ms/step - accuracy: 0.5862 - loss: 0.6779 - val_accuracy: 0.3444 - val_loss: 0.6607
# Epoch 2/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6054 - loss: 0.6034 - val_accuracy: 0.9778 - val_loss: 0.4805
# Epoch 3/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8144 - loss: 0.5202 - val_accuracy: 0.8889 - val_loss: 0.4165
# Epoch 4/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9252 - loss: 0.3768 - val_accuracy: 1.0000 - val_loss: 0.1834
# Epoch 5/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9599 - loss: 0.2549 - val_accuracy: 0.9778 - val_loss: 0.1580
# Epoch 6/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9695 - loss: 0.1278 - val_accuracy: 1.0000 - val_loss: 0.0236
# Epoch 7/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9870 - loss: 0.0766 - val_accuracy: 0.9889 - val_loss: 0.0463
# Epoch 8/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9886 - loss: 0.0431 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 9/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9910 - loss: 0.0261 - val_accuracy: 1.0000 - val_loss: 0.0199
# Epoch 10/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9886 - loss: 0.0372 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 11/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9915 - loss: 0.0353 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 12/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9929 - loss: 0.0189 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 13/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9957 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 14/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 15/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9914 - loss: 0.0165 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 16/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 17/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0138
# Epoch 18/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 19/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 20/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 21/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 9.8721e-04
# Epoch 22/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 9.1840e-04
# Epoch 23/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 8.7096e-04
# Epoch 24/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 8.3531e-04
# Epoch 25/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 8.0607e-04
# Epoch 26/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 7.8112e-04
# Epoch 27/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 7.5957e-04
# Epoch 28/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 7.4005e-04
# Epoch 29/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 7.2169e-04
# Epoch 30/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 7.0472e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step
# Epoch 1/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 8s 488ms/step - accuracy: 0.5276 - loss: 0.6883 - val_accuracy: 0.4222 - val_loss: 0.7008
# Epoch 2/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6551 - loss: 0.6329 - val_accuracy: 0.7222 - val_loss: 0.5979
# Epoch 3/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9148 - loss: 0.5154 - val_accuracy: 0.7889 - val_loss: 0.4856
# Epoch 4/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9312 - loss: 0.3527 - val_accuracy: 0.8667 - val_loss: 0.3437
# Epoch 5/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9858 - loss: 0.1847 - val_accuracy: 0.8667 - val_loss: 0.3278
# Epoch 6/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9890 - loss: 0.0931 - val_accuracy: 0.8444 - val_loss: 0.3925
# Epoch 7/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9900 - loss: 0.0423 - val_accuracy: 0.9000 - val_loss: 0.3317
# Epoch 8/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9943 - loss: 0.0210 - val_accuracy: 0.8778 - val_loss: 0.5042
# Epoch 9/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.9333 - val_loss: 0.3019
# Epoch 10/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9111 - val_loss: 0.3461
# Epoch 11/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.8889 - val_loss: 0.4706
# Epoch 12/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.8889 - val_loss: 0.5727
# Epoch 13/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.8778 - val_loss: 0.6447
# Epoch 14/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8667 - val_loss: 0.6909
# Epoch 15/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8667 - val_loss: 0.7080
# Epoch 16/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8667 - val_loss: 0.7052
# Epoch 17/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8778 - val_loss: 0.6882
# Epoch 18/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8778 - val_loss: 0.6633
# Epoch 19/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8778 - val_loss: 0.6327
# Epoch 20/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.8889 - val_loss: 0.6047
# Epoch 21/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8889 - val_loss: 0.5808
# Epoch 22/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8889 - val_loss: 0.5623
# Epoch 23/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9000 - val_loss: 0.5478
# Epoch 24/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9000 - val_loss: 0.5374
# Epoch 25/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9000 - val_loss: 0.5287
# Epoch 26/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9000 - val_loss: 0.5233
# Epoch 27/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9000 - val_loss: 0.5203
# Epoch 28/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9000 - val_loss: 0.5190
# Epoch 29/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9000 - val_loss: 0.5201
# Epoch 30/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9000 - val_loss: 0.5235
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 317ms/step
# Epoch 1/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 489ms/step - accuracy: 0.4662 - loss: 0.7246 - val_accuracy: 0.4333 - val_loss: 0.6630
# Epoch 2/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8062 - loss: 0.5882 - val_accuracy: 0.9889 - val_loss: 0.4669
# Epoch 3/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9301 - loss: 0.4536 - val_accuracy: 0.9333 - val_loss: 0.3382
# Epoch 4/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9589 - loss: 0.2643 - val_accuracy: 0.9889 - val_loss: 0.1152
# Epoch 5/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9839 - loss: 0.1288 - val_accuracy: 1.0000 - val_loss: 0.0384
# Epoch 6/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9890 - loss: 0.0702 - val_accuracy: 0.9889 - val_loss: 0.0374
# Epoch 7/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9910 - loss: 0.0399 - val_accuracy: 0.9889 - val_loss: 0.0228
# Epoch 8/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0198 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 9/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 1.0000 - val_loss: 0.0112
# Epoch 10/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.9889 - val_loss: 0.0203
# Epoch 11/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9889 - val_loss: 0.0170
# Epoch 12/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 13/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 14/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 15/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 16/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 17/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 18/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 19/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 20/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 21/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 22/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 23/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 24/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 25/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 26/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 27/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 28/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 29/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 30/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0016
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step
# Average Accuracy:  0.9422222222222223
# Average Precision:  0.9423981251723188

# %% [markdown]
# ## Saving Model

# %%
# Save the trained model
model.save('idd_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Testing and Predicting

# %%
import numpy as np
import scipy.io
import mne
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import tkinter as tk
from tkinter import filedialog

model = load_model('idd_model.h5')

def extract_top_channels(eeg_data, top_channels, channel_names):
    selected_indices = [channel_names.index(ch) for ch in top_channels]
    return eeg_data[:, selected_indices, :]

def predict_idd(uploaded_eeg_path):
    eeg_data = scipy.io.loadmat(uploaded_eeg_path)['clean_data']
    channel_names = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']
    ch_types = ['eeg'] * 14
    sampling_freq = 128
    info = mne.create_info(channel_names, ch_types=ch_types, sfreq=sampling_freq)
    info.set_montage('standard_1020')
    data = mne.io.RawArray(eeg_data, info)
    data.set_eeg_reference()
    data.notch_filter(freqs=50)
    data.filter(l_freq=1, h_freq=30)
    epochs = mne.make_fixed_length_epochs(data, duration=4, overlap=0)
    eeg_data = epochs.get_data()
    eeg_data_selected = extract_top_channels(eeg_data, top_channels, channel_names)

    class StandardScaler3D:
        def __init__(self):
            self.scaler = StandardScaler()
    
        def fit(self, X):
            self.scaler.fit(X.reshape(-1, X.shape[2]))
            return self
    
        def transform(self, X):
            return self.scaler.transform(X.reshape(-1, X.shape[2])).reshape(X.shape)
    
        def fit_transform(self, X):
            return self.scaler.fit_transform(X.reshape(-1, X.shape[2])).reshape(X.shape)

    scaler = StandardScaler3D()
    eeg_data_scaled = scaler.fit_transform(eeg_data_selected)

    if eeg_data_scaled.shape[0] > 1:
        eeg_data_scaled = eeg_data_scaled[0:1]
        eeg_data_scaled = eeg_data_scaled.transpose(0, 2, 1)

    prediction_probs = model.predict(eeg_data_scaled)
    prediction = (prediction_probs > 0.7).astype(int)
    prediction_percentage = prediction_probs[0][0] * 100

    if prediction[0] == 1:
        print(f"Prediction: IDD detected! (Probability: {prediction_percentage:.2f}%)")
    else:
        print(f"Prediction: No IDD detected! (Probability: {prediction_percentage:.2f}%)")
    
    return prediction, prediction_percentage

def upload_and_predict():
    file_path = filedialog.askopenfilename(title="Select EEG MAT file", filetypes=[("MAT files", "*.mat")])
    if file_path:
        prediction, prediction_percentage = predict_idd(file_path)
        result_label.config(text=f"Prediction: {'IDD detected' if prediction[0] == 1 else 'No IDD detected'}\nProbability: {prediction_percentage:.2f}%")

root = tk.Tk()
root.title("IDD Prediction from EEG")

upload_button = tk.Button(root, text="Upload EEG Signal", command=upload_and_predict)
upload_button.pack(pady=20)

result_label = tk.Label(root, text="Prediction: Not yet predicted")
result_label.pack(pady=10)

root.mainloop()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Creating RawArray with float64 data, n_channels=14, n_times=15360
#     Range : 0 ... 15359 =      0.000 ...   119.992 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 512 original time points ...
# 0 bad epochs dropped
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Prediction: IDD detected! (Probability: 99.86%)
